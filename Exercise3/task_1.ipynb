# %%
from pathlib import Path

import contextily as cx
import geopandas as gpd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import numpy as np
import pandas as pd
import polars as pl
import seaborn as sns
from sklearn.linear_model import LinearRegression

mpl.rcParams['axes.formatter.limits'] = (-100, 100)
sns.set_theme()

# %%
cities = sorted([c.lower() for c in ["Bern", "Zurich", "Manchester", "Hamburg", "Bordeaux"]])

detectors = pl.scan_csv("./data/detectors_public.csv", schema_overrides={"limit": pl.Utf8}).filter(
    pl.col("citycode").is_in(cities))

detector_df = detectors.collect()

# %%
pdf = detector_df.to_pandas()

pdf["lat"] = pd.to_numeric(pdf["lat"], errors="coerce")
pdf["long"] = pd.to_numeric(pdf["long"], errors="coerce")

gdf = gpd.GeoDataFrame(
    pdf,
    geometry=gpd.points_from_xy(pdf["long"], pdf["lat"]),
    crs="EPSG:4326"
)

# %%
for city in cities:
    out_path = Path(f'./plots/maps/{city}_detector_locations.png')

    # Skip if already generated
    if out_path.exists():
        continue

    mask = gdf['citycode'] == city
    city_df = gdf[mask]

    ax = city_df.plot(
        figsize=(12, 7),
        markersize=5,
        column='fclass',
        legend=True,
        categorical=True
    )
    cx.add_basemap(ax, crs=gdf.crs, source=cx.providers.Esri.WorldGrayCanvas)

    out_path.parent.mkdir(parents=True, exist_ok=True)
    plt.savefig(out_path, dpi=300)
    plt.close()

# %%
# -------------------------------------------------------------------
# 0) Config: cities + per-fclass capacity (veh/h/lane)
# -------------------------------------------------------------------
fclass_capacity = {
    "motorway": 2200,
    "motorway_link": 2000,
    "trunk": 2000,
    "trunk_link": 1800,
    "primary": 1600,
    "primary_link": 1500,
    "secondary": 1400,
    "secondary_link": 1300,
    "tertiary": 1100,
    "residential": 600,
    "service": 400,
    "other": 800,
}

# -------------------------------------------------------------------
# 1) Lazy UTD with timestamp
# -------------------------------------------------------------------
utd = (
    pl.scan_csv(
        "./data/utd19_u.csv",
        schema_overrides={
            "day": pl.Date,
            "flow": pl.Float64,
            "interval": pl.Int64,
            "speed": pl.Float64,
            "fclass": pl.Categorical,
        },
    )
    .filter(pl.col("city").is_in(cities))
    .with_columns(
        (
                pl.col("day").cast(pl.Datetime)
                + pl.duration(seconds=pl.col("interval"))
        ).alias("timestamp")
    )
)

# detectors: assumed to be a lazy frame with at least: detid, lanes, error, city, etc.
# detectors = pl.scan_csv("./data/detectors.csv")

# -------------------------------------------------------------------
# 2) Base lazy join (no cleaning yet)
# -------------------------------------------------------------------
result_lazy = utd.join(detectors, on="detid", how="left")

# -------------------------------------------------------------------
# 3) RAW data: collect and plot BEFORE any cleaning
# -------------------------------------------------------------------
result_raw = result_lazy.collect()

for city in cities:
    city_df = result_raw.filter(pl.col("city") == city)

    # --- target file paths ---
    hist_path = Path(f"./plots/histograms/error/{city}_error_histogram_raw.png")
    box_path = Path(f"./plots/boxplots/flow/{city}_flow_boxplots_raw.png")

    # --- ERROR HISTOGRAM (raw) ---
    if not hist_path.exists():
        err_series = city_df["error"].fill_null(0.0).to_numpy()

        plt.figure()
        plt.hist(err_series, bins=30)
        plt.title(f"{city.capitalize()} Error Distribution (raw)")
        plt.xlabel("Error")
        plt.ylabel("Count")
        plt.tight_layout()
        hist_path.parent.mkdir(parents=True, exist_ok=True)
        plt.savefig(hist_path, dpi=300)
        plt.close()

    # --- FLOW-PER-LANE BOX PLOTS (raw) ---
    if not box_path.exists():
        city_df = city_df.with_columns(
            (pl.col("flow") / pl.col("lanes")).alias("flow_per_lane")
        )
        pdf = city_df.to_pandas()

        g = sns.catplot(
            data=pdf,
            x="flow_per_lane",
            y="fclass",
            kind="box",
            height=6,
            aspect=1.6,
        )
        g.set_axis_labels("Flow [veh/h/lane]", "Road Type")
        g.figure.suptitle(
            f"Boxplots for Flow per Road Type (raw) – {city.capitalize()}",
            y=1.02,
        )
        g.fig.tight_layout()
        box_path.parent.mkdir(parents=True, exist_ok=True)
        g.fig.savefig(box_path, dpi=300)
        plt.close(g.fig)

# -------------------------------------------------------------------
# 4) CLEANED pipeline: error filter + fclass-based flow caps
# -------------------------------------------------------------------
result_clean_lazy = (
    result_lazy
    .with_columns([
        pl.col("error").fill_null(0.0),
        (pl.col("flow") / pl.col("lanes")).alias("flow_per_lane"),
        # map fclass -> capacity; cast to float so non-matches become null
        pl.col("fclass")
        .replace(fclass_capacity)
        .cast(pl.Float64, strict=False)
        .alias("max_flow_per_lane"),
    ])
    .filter(pl.col("error") != 1.0)
    # only keep rows where we have a numeric capacity
    .filter(pl.col("max_flow_per_lane").is_not_null())
    # class-based flow cleaning
    .filter(
        (pl.col("flow_per_lane") >= 0)
        & (pl.col("flow_per_lane") <= pl.col("max_flow_per_lane"))
    )
)
result_clean_lazy = result_clean_lazy.with_columns(
    pl.when(pl.col("city") == "manchester").then(pl.col("occ") / 100).otherwise(pl.col("occ")).alias("occ")).filter(
    pl.col("occ") <= 1.0)

# -------------------------------------------------------------------
# 5) Collect cleaned DF for all further analysis/MFDs
# -------------------------------------------------------------------
total_df = result_clean_lazy.collect()

# %%
for city in cities:
    city_df = total_df.filter(pl.col("city") == city)
    occ_series = city_df["occ"].drop_nulls()
    if occ_series.len() == 0:
        continue

    data = city_df.to_pandas()
    g = sns.catplot(data, x="occ", y="fclass", kind="box")
    g.set_ylabels("Road Type")
    g.set_xlabels("Occupancy [%]")
    g.figure.suptitle(f"Boxplots for Occupancy per Road Type for {city.capitalize()}")
    g.tight_layout()
    g.savefig(f"./plots/boxplots/occupancy/{city}_occupancy_boxplots.png", dpi=300)
    plt.close(g.figure)

# %%
for city in cities:
    city_df = total_df.filter(pl.col("city") == city)

    speed_series = city_df["speed"].drop_nulls()
    if speed_series.len() == 0:
        continue

    data = city_df.to_pandas()
    g = sns.catplot(data, x="speed", y="fclass", kind="box")
    g.set_ylabels("Road Type")
    g.set_xlabels("Speed [km/h]")
    g.figure.suptitle(f"Boxplots for Speed per Road Type for {city.capitalize()}")
    g.tight_layout()
    g.savefig(f"./plots/boxplots/speed/{city}_speed_boxplots.png", dpi=300)
    plt.close(g.figure)

# %%
for city in cities:
    city_df = total_df.filter(pl.col("city") == city)

    flow_series = city_df["flow"].drop_nulls()
    if flow_series.len() == 0:
        continue

    data = city_df.to_pandas()
    plt.figure()
    sns.histplot(data, x="flow")
    plt.title(f"{city.capitalize()} Flow Distribution")
    plt.xlabel("Flow [veh/h/lane]")
    plt.tight_layout()
    plt.savefig(f'./plots/histograms/flow/{city}_flow_histogram.png', dpi=300)
    plt.close()

# %%
for city in cities:
    city_df = total_df.filter(pl.col("city") == city)
    occ_series = city_df["occ"].drop_nulls()
    if occ_series.len() == 0:
        continue

    data = city_df.to_pandas()
    plt.figure()
    sns.histplot(data, x="occ")
    plt.title(f"{city.capitalize()} Occupancy Distribution")
    plt.xlabel("Occupancy [%]")
    plt.tight_layout()
    plt.savefig(f'./plots/histograms/occupancy/{city}_occupancy_histogram.png', dpi=300)
    plt.close()

# %%
for city in cities:
    city_df = total_df.filter(pl.col("city") == city)
    speed_series = city_df["speed"].drop_nulls()
    if speed_series.len() == 0:
        continue

    data = city_df.to_pandas()
    plt.figure()
    sns.histplot(data, x="speed")
    plt.title(f"{city.capitalize()} Speed Distribution")
    plt.xlabel("Speed [km/h]")
    plt.tight_layout()
    plt.savefig(f'./plots/histograms/speed/{city}_speed_histogram.png', dpi=300)
    plt.close()

# %%
for city in cities:
    city_df = total_df.filter(pl.col("city") == city)
    summary_df = city_df[["flow", "occ", "speed"]]
    summary = summary_df.describe()
    psummary = summary.to_pandas()
    print(psummary.to_latex(index=False, na_rep='--', float_format="%.2f", bold_rows=True, column_format="r|lll",
                            caption=f"Summary Table for {city.capitalize()}", label=f"tab:summary-{city}"))
# Out:
# \begin{table}
# \caption{Summary Table for Bern}
# \label{tab:summary-bern}
# \begin{tabular}{r|lll}
# \toprule
# statistic & flow & occ & speed \\
# \midrule
# count & 773409.00 & 773409.00 & 0.00 \\
# null_count & 0.00 & 0.00 & 773409.00 \\
# mean & 200.96 & 0.14 & -- \\
# std & 162.01 & 0.18 & -- \\
# min & 0.00 & 0.00 & -- \\
# 25% & 60.20 & 0.01 & -- \\
# 50% & 180.00 & 0.06 & -- \\
# 75% & 299.40 & 0.19 & -- \\
# max & 1993.00 & 1.00 & -- \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \caption{Summary Table for Bordeaux}
# \label{tab:summary-bordeaux}
# \begin{tabular}{r|lll}
# \toprule
# statistic & flow & occ & speed \\
# \midrule
# count & 544305.00 & 544305.00 & 0.00 \\
# null_count & 0.00 & 0.00 & 544305.00 \\
# mean & 371.20 & 0.09 & -- \\
# std & 332.35 & 0.14 & -- \\
# min & 0.00 & 0.00 & -- \\
# 25% & 108.00 & 0.01 & -- \\
# 50% & 288.00 & 0.04 & -- \\
# 75% & 528.00 & 0.09 & -- \\
# max & 3180.00 & 1.00 & -- \\
# \bottomrule
# \end{tabular}
# ...

# %%
mfd = (
    total_df
    .group_by(["city", "timestamp"])
    .agg([
        pl.mean("flow").alias("Q"),
        pl.mean("occ").alias("O"),
        (pl.col("flow") / pl.col("speed")).mean().alias("K"),
    ])
)
mfd.head()
# Out:
# shape: (5, 5)
# ┌─────────┬─────────────────────┬────────────┬──────────┬──────┐
# │ city    ┆ timestamp           ┆ Q          ┆ O        ┆ K    │
# │ ---     ┆ ---                 ┆ ---        ┆ ---      ┆ ---  │
# │ str     ┆ datetime[μs]        ┆ f64        ┆ f64      ┆ f64  │
# ╞═════════╪═════════════════════╪════════════╪══════════╪══════╡
# │ zurich  ┆ 2015-11-01 15:51:00 ┆ 275.053974 ┆ 0.122536 ┆ null │
# │ hamburg ┆ 2016-12-03 02:48:00 ┆ 85.72973   ┆ 0.047712 ┆ null │
# │ hamburg ┆ 2016-11-14 18:51:00 ┆ 319.90991  ┆ 0.266456 ┆ null │
# │ hamburg ┆ 2016-09-07 12:57:00 ┆ 296.031746 ┆ 0.211283 ┆ null │
# │ hamburg ┆ 2016-09-22 14:33:00 ┆ 315.447154 ┆ 0.233821 ┆ null │
# └─────────┴─────────────────────┴────────────┴──────────┴──────┘

# %%
day_dict = {1: "Monday", 2: "Tuesday", 7: "Sunday"}
weekdays = [1, 2, 7]

for city in cities:
    city_df = mfd.filter(pl.col("city") == city)

    fig, axes = plt.subplots(3, figsize=(12, 12), sharex=True)
    fig.suptitle(f"MFD for {city.capitalize()}")

    for i, d in enumerate(weekdays):
        day_df = city_df.filter(pl.col("timestamp").dt.weekday() == d)

        axes[i].scatter(day_df["O"], day_df["Q"])

        axes[i].set_title(day_dict[d])
        axes[i].set_xlabel("Occupancy")
        axes[i].set_ylabel("Flow [veh/h]")
        axes[i].xaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))

    plt.savefig(f"./plots/mfd/{city}_daily_mfd.png", dpi=300)
    plt.close()

# %%
for city in cities:
    # 1. Filter data for the current city (All days included)
    city_df = mfd.filter(pl.col("city") == city)

    # 2. Create a single plot (instead of 3 subplots)
    fig, ax = plt.subplots(figsize=(10, 7))

    x_col = "O"
    x_label = "Occupancy"

    # 4. Plot all data points
    # alpha=0.3 helps visualize point density where data overlaps
    ax.scatter(city_df[x_col], city_df["Q"], s=3, alpha=0.3, color="tab:blue")

    # 5. Labels and Titles
    ax.set_title(f"MFD for {city.capitalize()}")
    ax.set_xlabel(x_label)
    ax.set_ylabel("Flow [veh/h]")
    ax.xaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
    ax.grid(True, alpha=0.3)

    # 6. Save
    plt.tight_layout()
    plt.savefig(f"./plots/mfd/{city}_mfd.png", dpi=300)
    plt.close()

# %%
city_mfd_coef = {}

for city in cities:
    # 1. Filter for the entire city dataset (no day filtering)
    base_df = mfd.filter(pl.col("city") == city)

    # 2. Select X (Occupancy/Density) and Y (Flow) based on city
    # Zurich/Others: Use Occupancy (O)
    data_df = base_df.filter(
        pl.col("Q").is_not_null() & pl.col("Q").is_not_nan() &
        pl.col("O").is_not_null() & pl.col("O").is_not_nan()
    )
    x = data_df["O"].to_numpy()

    Q = data_df["Q"].to_numpy()

    # 3. Final safety check for empty data
    if len(Q) < 3:
        print(f"Not enough data for {city}")
        city_mfd_coef[city] = (None, None)
        continue

    # 4. Prepare Linear Regression
    # We fit Q = alpha * x + (-beta) * x^2
    # This forces the parabola to pass through (0,0)
    X = np.column_stack([x, x ** 2])

    model = LinearRegression(fit_intercept=False)
    model.fit(X, Q)

    # 5. Extract Coefficients
    alpha, minus_beta = model.coef_
    beta = -minus_beta

    # Store directly under the city key
    city_mfd_coef[city] = (alpha, beta)

    # Optional: Print results to verify
    print(
        f"{city.capitalize()}: Flow Factor (u_0)={alpha:.2f} [veh/h/%], Crtical Occupancy={alpha / (2 * beta):.4%}, Jam Occupancy={alpha / beta:.4%}")
# Out:
# Bern: Flow Factor (u_0)=1901.03 [veh/h/%], Crtical Occupancy=43.2056%, Jam Occupancy=86.4111%
# Bordeaux: Flow Factor (u_0)=6593.97 [veh/h/%], Crtical Occupancy=19.6578%, Jam Occupancy=39.3156%
# Hamburg: Flow Factor (u_0)=2210.38 [veh/h/%], Crtical Occupancy=31.7041%, Jam Occupancy=63.4082%
# Manchester: Flow Factor (u_0)=3921.16 [veh/h/%], Crtical Occupancy=39.5921%, Jam Occupancy=79.1842%
# Zurich: Flow Factor (u_0)=3144.16 [veh/h/%], Crtical Occupancy=21.9419%, Jam Occupancy=43.8838%

# %%
for city in cities:
    # 1. Filter for ALL data for this city
    city_df = mfd.filter(pl.col("city") == city)

    # 2. Setup Plotting Parameters based on City
    if city != "innsbruck":
        x_col = "O"
        x_label = "Occupancy"
        use_percent = True

        # Formatter for annotation
        line_label = lambda k_crit, k_jam, alpha: (
            f"{'Critical Occupancy:':<20}{k_crit:>7.2%}\n"
            f"{'Jam Occupancy:':<20}{k_jam:>7.2%}"
        )
    else:
        x_col = "K"
        x_label = "Density [veh/km]"
        use_percent = False

        # Formatter for annotation (includes speeds)
        line_label = lambda k_crit, k_jam, alpha: (
            f"{'Critical Density:':<20} {k_crit:>7.2f} veh/km\n"
            f"{'Jam Density:':<20} {k_jam:>7.2f} veh/km\n"
            f"{'Freeflow Velocity:':<20} {alpha:>7.2f} km/h\n"
            f"{'Backward wave speed:':<20} {alpha / 2:>7.2f} km/h"
        )

    # 3. Create Single Figure
    fig, ax = plt.subplots(figsize=(10, 8))
    fig.suptitle(f"MFD for {city.capitalize()}")

    # 4. Prepare Data
    plot_data = city_df.select([x_col, "Q"]).drop_nulls()
    x = plot_data[x_col].to_numpy()
    Q = plot_data["Q"].to_numpy()

    # 5. Scatter Plot (Raw Data)
    ax.scatter(x, Q, s=3, alpha=0.3, label="Data", color="tab:blue")

    # 6. Plot Fitted Curve (if coefficients exist)
    # We now access the flat dictionary directly
    coefs = city_mfd_coef.get(city)

    if coefs and coefs[0] is not None:
        alpha, beta = coefs

        if alpha > 0 and beta > 0:
            # Physical parameters
            k_crit = alpha / (2 * beta)  # Peak flow location
            k_jam = alpha / beta  # Q=0 location
            q_crit = alpha ** 2 / (4 * beta)  # Peak flow value

            # Draw Parabola
            x_line = np.linspace(0, k_jam, 200)
            Q_fit = alpha * x_line - beta * x_line ** 2
            ax.plot(x_line, Q_fit, color="r", linewidth=2, label="Parabolic Fit")

            # Draw Critical Point (Vertical line + Dot)
            ax.vlines(k_crit, 0, q_crit, color="r", linestyles="--")
            ax.scatter([k_crit], [q_crit], color="r", zorder=5, label="Critical Point")

            # Add Annotation Box
            ax.annotate(
                line_label(k_crit, k_jam, alpha),
                xy=(0.98, 0.98),
                xycoords="axes fraction",
                ha="right",
                va="top",
                bbox=dict(boxstyle="square", fc="white", ec="black", alpha=0.9),
                family="monospace"  # Ensures alignment of text
            )

    # 7. Final Formatting
    if use_percent:
        # Assuming input data is 0.0-1.0 (fractions)
        ax.xaxis.set_major_formatter(mtick.PercentFormatter(xmax=1.0))

    ax.set_xlabel(x_label)
    ax.set_ylabel("Flow [veh/h]")
    ax.legend(loc="upper right", bbox_to_anchor=(1, 0.85))  # Move legend slightly down to avoid textbox
    ax.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(f"./plots/mfd/{city}_mfd_with_fit.png", dpi=300)
    plt.close()

# %%
L = 0.005  # average vehicle length in km
LD = 0.0015  # average detector length in km

density_df = total_df.with_columns(
    pl.when(pl.col("city") != "manchester").then(
        pl.col("occ") * pl.col("lanes") / (L + LD)).otherwise(
        pl.col("flow") / pl.col("speed")).alias("density"))

density_mfd = (
    density_df
    .group_by(["city", "timestamp"])
    .agg([
        pl.mean("flow").alias("Q"),
        pl.mean("density").alias("K"),
    ])
)
density_mfd = density_mfd.drop_nans()

# %%
for city in cities:
    # 1. Filter data for the city (All days included)
    city_df = density_mfd.filter(pl.col("city") == city)

    # 2. Create Single Figure
    fig, ax = plt.subplots(figsize=(10, 7))

    # 3. Extract Data
    K = city_df["K"].to_numpy()
    Q = city_df["Q"].to_numpy()

    # 4. Scatter Plot
    # s=3 (small size) and alpha=0.3 (transparency) are crucial for visualizing
    # where the data is most dense versus outliers.
    ax.scatter(K, Q, s=3, alpha=0.3, color="tab:blue")

    # 5. Labels & Titles
    ax.set_title(f"MFD for {city.capitalize()}")
    ax.set_xlabel("Density [veh/km]")
    ax.set_ylabel("Flow [veh/h]")
    ax.grid(True, alpha=0.3)

    # 6. Save
    plt.tight_layout()
    plt.savefig(f"./plots/mfd/{city}_mfd_density.png", dpi=300)
    plt.close()

# %%
city_density_mfd_coef = {}

for city in cities:
    # 1. Filter base DF per city
    city_df = density_mfd.filter(pl.col("city") == city)

    # 2. Clean Data: Drop nulls/NaNs
    # (Strict Q>0 is not required for Parabolic, but removing nulls is essential)
    fit_data = city_df.filter(
        pl.col("Q").is_not_null() & pl.col("Q").is_not_nan() &
        pl.col("K").is_not_null() & pl.col("K").is_not_nan()
    )

    K = fit_data["K"].to_numpy()
    Q = fit_data["Q"].to_numpy()

    from scipy.optimize import curve_fit
    import numpy as np


    def q_exp(K, q_max, a):
        return q_max * (1 - np.exp(-a * K))


    if len(Q) > 10:
        try:
            # Initial guesses help convergence
            q0 = [np.max(Q), 0.01]

            # Nonlinear least squares fit
            popt, _ = curve_fit(
                q_exp,
                K,
                Q,
                p0=q0,
                bounds=(0, np.inf)  # enforce physical positivity
            )

            q_max, a = popt

            # Physical validity check
            if q_max > 0 and a > 0:
                city_density_mfd_coef[city] = (q_max, a)

                # Optional characteristic density (63% of Qmax)
                k_char = 1 / a

                print(
                    f"{city}: Fitted Exponential. "
                    f"Q_max={q_max:.1f} veh/h, "
                    f"K_char={k_char:.1f} veh/km"
                )
            else:
                print(f"{city}: Invalid fit (non-physical parameters).")
                city_density_mfd_coef[city] = (None, None)

        except RuntimeError:
            print(f"{city}: Fit did not converge.")
            city_density_mfd_coef[city] = (None, None)

    else:
        city_density_mfd_coef[city] = (None, None)
# Out:
# bern: Fitted Exponential. Q_max=560.4 veh/h, K_char=42.1 veh/km
# bordeaux: Fitted Exponential. Q_max=750.3 veh/h, K_char=18.7 veh/km
# hamburg: Fitted Exponential. Q_max=464.1 veh/h, K_char=30.0 veh/km
# manchester: Fitted Exponential. Q_max=1012.2 veh/h, K_char=23.3 veh/km
# zurich: Fitted Exponential. Q_max=382.6 veh/h, K_char=14.7 veh/km

# %%
import numpy as np
import matplotlib.pyplot as plt

# Exponential model: Q = Qmax * (1 - exp(-a K))
q_exp = lambda K, q_max, a: q_max * (1 - np.exp(-a * K))

# Formatter for Exponential Saturation Model
# Parameters: Qmax, a, vf (= Qmax*a), characteristic density (=1/a)
line_label_exp = lambda q_max, a: (
    f"{'$Q_{max}$:':<1} {q_max:>12.2f} veh/h{'':>7}\n"
    f"{'$a$:':<10} {a:>8.4f} 1/(veh/km)\n"
    f"{'$v_f$:':<1} {(q_max * a):>12.2f} km/h{'':>8}\n"
    f"{'$K_{63}~(=1/a)$:':<1} {(1 / a):>12.2f} veh/km{'':>6}"
)

for city in cities:
    city_df = density_mfd.filter(pl.col("city") == city)

    fig, ax = plt.subplots(figsize=(10, 8))
    fig.suptitle(f"MFD for {city.capitalize()}")

    x_col = "K"
    x_label = "Density [veh/km]"

    plot_data = city_df.select([x_col, "Q"]).drop_nulls()
    x = plot_data[x_col].to_numpy()
    Q = plot_data["Q"].to_numpy()

    ax.scatter(x, Q, s=3, alpha=0.3, label="Data", color="tab:blue")

    # Expecting stored as (q_max, a) now
    coefs = city_density_mfd_coef.get(city)

    if coefs and coefs[0] is not None:
        q_max, a = coefs

        if q_max > 0 and a > 0:
            # Plot curve over observed density range (or from 0 to max observed)
            x_line = np.linspace(0, np.max(x), 200)
            Q_fit = q_exp(x_line, q_max, a)

            ax.plot(x_line, Q_fit, color="r", linewidth=2, label="Exponential Fit")

            # Mark K_63 (where Q = 0.632 * Qmax)
            k_63 = 1 / a
            q_63 = q_exp(k_63, q_max, a)
            ax.vlines(k_63, 0, q_63, color="r", linestyles="--", linewidth=1)
            ax.scatter([k_63], [q_63], color="r", zorder=5, label="$K_{63}$ point")

            ax.annotate(
                line_label_exp(q_max, a),
                xy=(0.02, 0.98),
                xycoords="axes fraction",
                ha="left",
                va="top",
                bbox=dict(boxstyle="square", fc="white", ec="black", alpha=0.9),
                family="monospace",
                fontsize=10
            )

    ax.set_xlabel(x_label)
    ax.set_ylabel("Flow [veh/h]")
    ax.legend(loc="upper right", bbox_to_anchor=(1, 0.85))
    ax.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(f"./plots/mfd/{city}_mfd_with_fit_density.png", dpi=300)
    plt.close()

# %%
manchester_df = total_df.filter(pl.col("city") == "manchester").with_columns(
    (pl.col("flow") / pl.col("speed")).alias("density")).select(
    ["timestamp", "detid", "flow", "density", "occ", "speed"])
congestion_df = manchester_df.group_by("detid").agg(
    (pl.mean("speed") / pl.quantile("speed", 0.9)).alias("congestion")
)
manchester_df = manchester_df.join(congestion_df, how="left", on="detid")

top20_df = manchester_df.filter(pl.col("congestion") > pl.quantile("congestion", 0.8))
less80_df = manchester_df.filter(pl.col("congestion") <= pl.quantile("congestion", 0.8))

# %%
print(len(top20_df.select("detid").unique()))
print(len(less80_df.select("detid").unique()))
print(len(manchester_df.select("detid").unique()))
print(manchester_df.select("congestion").quantile(0.8))
# Out:
# 27
# 120
# 147
# shape: (1, 1)
# ┌────────────┐
# │ congestion │
# │ ---        │
# │ f64        │
# ╞════════════╡
# │ 0.856846   │
# └────────────┘

# %%
top20_mfd = top20_df.group_by("timestamp").agg(
    pl.mean("flow"),
    pl.mean("density"),
    pl.mean("occ"),
    pl.var("occ").alias("var_occ")
).sort("timestamp")
less80_mfd = less80_df.group_by("timestamp").agg(
    pl.mean("flow"),
    pl.mean("density"),
    pl.mean("occ"),
    pl.var("occ").alias("var_occ")
).sort("timestamp")
manchester_mfd = manchester_df.group_by("timestamp").agg(
    pl.mean("flow"),
    pl.mean("density"),
    pl.mean("occ"),
    pl.var("occ").alias("var_occ")
).sort("timestamp")

# %%
fig, axes = plt.subplots(2, figsize=(12, 10), sharex=True)

# Combine first two scatters
axes[0].scatter(top20_mfd["density"], top20_mfd["flow"], alpha=0.3, s=15, label="Top 20%")
axes[0].scatter(less80_mfd["density"], less80_mfd["flow"], alpha=0.3, s=15, label="Less 80%")
axes[0].set_ylabel("Flow [veh/h]")
axes[0].set_title("Top 20% and Less 80% Percentiles")
axes[0].legend()

# Manchester only
axes[1].scatter(manchester_mfd["density"], manchester_mfd["flow"], alpha=0.3, s=10)
axes[1].set_xlabel("Density [veh/km]")
axes[1].set_ylabel("Flow [veh/h]")
axes[1].set_title("Entirety of Manchester")

fig.suptitle("MFD for Manchester")
plt.tight_layout()
plt.savefig("./plots/congestion/congestion_mfd.png")
plt.show()

# %%
fig, axes = plt.subplots(3, figsize=(12, 12), sharex=True)
axes[0].plot(top20_mfd["timestamp"], top20_mfd["var_occ"])
axes[1].plot(less80_mfd["timestamp"], less80_mfd["var_occ"])
axes[2].plot(manchester_mfd["timestamp"], manchester_mfd["var_occ"])
axes[0].set_title("Top 20%-Percentile")
axes[0].set_ylabel("Variance $\sigma^2$")
axes[1].set_title("Less 80%-Percentile")
axes[1].set_ylabel("Variance $\sigma^2$")
axes[2].set_title("Entirety of Manchester")
axes[2].set_ylabel("Variance $\sigma^2$")
axes[2].set_xlabel("Time")
fig.suptitle("Variance of Occupancy in Manchester")
plt.tight_layout()
plt.savefig("./plots/congestion/variance.png", dpi=300)
plt.show()
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Julian\AppData\Local\Temp\ipykernel_20624\111609569.py:6: SyntaxWarning: invalid escape sequence '\s'
#   axes[0].set_ylabel("Variance $\sigma^2$")
# C:\Users\Julian\AppData\Local\Temp\ipykernel_20624\111609569.py:8: SyntaxWarning: invalid escape sequence '\s'
#   axes[1].set_ylabel("Variance $\sigma^2$")
# C:\Users\Julian\AppData\Local\Temp\ipykernel_20624\111609569.py:10: SyntaxWarning: invalid escape sequence '\s'
#   axes[2].set_ylabel("Variance $\sigma^2$")

# %%
fig, axes = plt.subplots(2, figsize=(12, 12), sharex=True)
axes[0].plot(top20_mfd["timestamp"], top20_mfd["var_occ"] / manchester_mfd["var_occ"])
axes[1].plot(less80_mfd["timestamp"], less80_mfd["var_occ"] / manchester_mfd["var_occ"])
axes[0].set_title("Top 20%-Percentile")
axes[0].set_ylabel("Variance Ratio")
axes[1].set_title("Less 80%-Percentile")
axes[1].set_ylabel("Variance Ratio")
axes[1].set_xlabel("Time")
fig.suptitle("Variance Ratio of Occupancy in Manchester")
plt.tight_layout()
plt.savefig("./plots/congestion/variance_ration.png", dpi=300)
plt.show()

# %%
print((top20_mfd["var_occ"] / manchester_mfd["var_occ"]).describe().to_pandas().to_latex(index=False,
                                                                                         caption="Description of Variance Ratios for Top 20%-Percentile",
                                                                                         label="tab:variance-ratio-20p",
                                                                                         float_format="%.2f",
                                                                                         escape=True))
# Out:
# \begin{table}
# \caption{Description of Variance Ratios for Top 20%-Percentile}
# \label{tab:variance-ratio-20p}
# \begin{tabular}{lr}
# \toprule
# statistic & value \\
# \midrule
# count & 6043.00 \\
# null\_count & 0.00 \\
# mean & 0.70 \\
# std & 0.29 \\
# min & 0.02 \\
# 25\% & 0.52 \\
# 50\% & 0.67 \\
# 75\% & 0.84 \\
# max & 3.99 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
print((less80_mfd["var_occ"] / manchester_mfd["var_occ"]).describe().to_pandas().to_latex(index=False,
                                                                                          caption="Description of Variance Ratios for Less 80%-Percentile",
                                                                                          label="tab:variance-ratio-80p",
                                                                                          float_format="%.2f",
                                                                                          escape=True))
# Out:
# \begin{table}
# \caption{Description of Variance Ratios for Less 80%-Percentile}
# \label{tab:variance-ratio-80p}
# \begin{tabular}{lr}
# \toprule
# statistic & value \\
# \midrule
# count & 6043.00 \\
# null\_count & 0.00 \\
# mean & 1.05 \\
# std & 0.08 \\
# min & 0.27 \\
# 25\% & 1.01 \\
# 50\% & 1.06 \\
# 75\% & 1.11 \\
# max & 1.26 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
q = pl.scan_csv("./data/utd19_u.csv", schema_overrides={
    "day": pl.Date,
    "flow": pl.Float64,
    "interval": pl.Int64,
    "speed": pl.Float64,
    "fclass": pl.Categorical,
}, ).filter(pl.col("city") == "manchester")
tmp = q.collect()
tmp
# Out:
# shape: (1_142_893, 8)
# ┌────────────┬──────────┬─────────┬────────┬───────────┬───────┬────────────┬───────────┐
# │ day        ┆ interval ┆ detid   ┆ flow   ┆ occ       ┆ error ┆ city       ┆ speed     │
# │ ---        ┆ ---      ┆ ---     ┆ ---    ┆ ---       ┆ ---   ┆ ---        ┆ ---       │
# │ date       ┆ i64      ┆ str     ┆ f64    ┆ f64       ┆ i64   ┆ str        ┆ f64       │
# ╞════════════╪══════════╪═════════╪════════╪═══════════╪═══════╪════════════╪═══════════╡
# │ 2017-09-29 ┆ 83400    ┆ N06111V ┆ 840.0  ┆ 26.25     ┆ null  ┆ manchester ┆ 32.0      │
# │ 2017-09-29 ┆ 83400    ┆ N06112W ┆ 780.0  ┆ 26.0      ┆ null  ┆ manchester ┆ 30.0      │
# │ 2017-09-29 ┆ 83400    ┆ N06113Y ┆ 996.0  ┆ 33.2      ┆ null  ┆ manchester ┆ 30.0      │
# │ 2017-09-29 ┆ 83400    ┆ N06114Z ┆ 828.0  ┆ 27.6      ┆ null  ┆ manchester ┆ 30.0      │
# │ 2017-09-29 ┆ 83400    ┆ N06121L ┆ 360.0  ┆ 21.176471 ┆ null  ┆ manchester ┆ 17.0      │
# ...

# %%
tmp = tmp.with_columns(pl.col("error").fill_null(0.0)).filter(pl.col("error") != 1.0)
tmp_pd = tmp.to_pandas()
sns.boxplot(tmp_pd, x="occ")
# Out:
# <Axes: xlabel='occ'>

# %%
tmp.select("occ").describe()
# Out:
# shape: (9, 2)
# ┌────────────┬───────────┐
# │ statistic  ┆ occ       │
# │ ---        ┆ ---       │
# │ str        ┆ f64       │
# ╞════════════╪═══════════╡
# │ count      ┆ 765096.0  │
# │ null_count ┆ 0.0       │
# │ mean       ┆ 19.168062 │
# │ std        ┆ 31.819728 │
# │ min        ┆ 0.0       │
# │ 25%        ┆ 4.114286  │
# │ 50%        ┆ 11.142857 │
# │ 75%        ┆ 23.576389 │
# │ max        ┆ 2094.0    │
# └────────────┴───────────┘

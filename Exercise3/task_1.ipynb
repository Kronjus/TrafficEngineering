# %%
import contextily as cx
import geopandas as gpd
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import polars as pl
import seaborn as sns

mpl.rcParams['axes.formatter.limits'] = (-100, 100)

# %%
cities = sorted([c.lower() for c in ["Bern", "Zurich", "Innsbruck", "Hamburg", "Bordeaux"]])

detectors = pl.scan_csv("./data/detectors_public.csv", schema_overrides={"limit": pl.Utf8}).filter(
    pl.col("citycode").is_in(cities))

detector_df = detectors.collect()

# %%
pdf = detector_df.to_pandas()

pdf["lat"] = pd.to_numeric(pdf["lat"], errors="coerce")
pdf["long"] = pd.to_numeric(pdf["long"], errors="coerce")

gdf = gpd.GeoDataFrame(
    pdf,
    geometry=gpd.points_from_xy(pdf["long"], pdf["lat"]),
    crs="EPSG:4326"
)

# %%
for city in cities:
    mask = gdf['citycode'] == city
    city_df = gdf[mask]
    ax = city_df.plot(figsize=(12, 7), markersize=5, column='fclass', legend=True, categorical=True)
    cx.add_basemap(ax, crs=gdf.crs)
    plt.savefig(f'./plots/maps/{city}_detector_locations.png', dpi=300)
    plt.close()

# %%
utd = (
    pl.scan_csv(
        "./data/utd19_u.csv",
        schema_overrides={
            "day": pl.Date,
            "flow": pl.Float64,
            "interval": pl.Int64,
            "speed": pl.Float64,
            "fclass": pl.Categorical
        },
    )
    .filter(pl.col("city").is_in(cities))
    .with_columns(
        (
                pl.col("day").cast(pl.Datetime)
                + pl.duration(seconds=pl.col("interval"))
        ).alias("timestamp")
    )
)

links = (
    pl.scan_csv("./data/links.csv")
    .filter(pl.col("citycode").is_in(cities))
)

result = utd.join(detectors, on="detid", how="left")

for city in cities:
    city_df = result.filter(pl.col("city") == city).collect()
    err_series = city_df["error"].fill_null(0.0)

    data = err_series.to_numpy()
    plt.figure()
    plt.hist(data)
    plt.title(f"{city.capitalize()} Error Distribution")
    plt.xlabel("Error")
    plt.tight_layout()
    plt.savefig(f"./plots/histograms/error/{city}_error_histotgram.png", dpi=300)
    plt.close()

result = result.with_columns(pl.col("error").fill_null(0.0)).filter(pl.col("error") != 1.0)
result = result.with_columns((pl.col("flow") / pl.col("lanes")).alias("flow_per_lane"))
result = result.filter(pl.col("flow_per_lane") <= 2500)
total_df = result.collect()

# %%
for city in cities:
    city_df = total_df.filter(pl.col("city") == city)
    data = city_df.to_pandas()
    plt.figure()
    sns.catplot(data, x="flow", y="fclass", kind="box")
    plt.ylabel("Road Type")
    plt.xlabel("Flow [veh/h/lane]")
    plt.title(f"Boxplots for Flow per Road Type for {city.capitalize()}")
    plt.tight_layout()
    plt.savefig(f"./plots/boxplots/flow/{city}_flow_boxplots.png", dpi=300)
    plt.close()

# %%
for city in cities:
    city_df = total_df.filter(pl.col("city") == city)
    occ_series = city_df["occ"].drop_nulls()
    if occ_series.len() == 0:
        continue

    data = city_df.to_pandas()
    plt.figure()
    sns.catplot(data, x="occ", y="fclass", kind="box")
    plt.ylabel("Road Type")
    plt.xlabel("Occupancy [%]")
    plt.title(f"Boxplots for Occupancy per Road Type for {city.capitalize()}")
    plt.tight_layout()
    plt.savefig(f"./plots/boxplots/occupancy/{city}_occupancy_boxplots.png", dpi=300)
    plt.close()

# %%
for city in cities:
    city_df = total_df.filter(pl.col("city") == city)

    speed_series = city_df["speed"].drop_nulls()
    if speed_series.len() == 0:
        continue

    data = city_df.to_pandas()
    plt.figure()
    sns.catplot(data, x="speed", y="fclass", kind="box")
    plt.ylabel("Road Type")
    plt.xlabel("Speed [km/h]")
    plt.title(f"Boxplots for Speed per Road Type for {city.capitalize()}")
    plt.tight_layout()
    plt.savefig(f"./plots/boxplots/speed/{city}_speed_boxplots.png", dpi=300)
    plt.close()

# %%
for city in cities:
    city_df = total_df.filter(pl.col("city") == city)

    flow_series = city_df["flow"].drop_nulls()
    if flow_series.len() == 0:
        continue

    data = city_df.filter(pl.col("flow") <= 2500).to_pandas()
    plt.figure()
    sns.histplot(data, x="flow")
    plt.title(f"{city.capitalize()} Flow Distribution")
    plt.xlabel("Flow [veh/h/lane]")
    plt.tight_layout()
    plt.savefig(f'./plots/histograms/flow/{city}_flow_histogram.png', dpi=300)
    plt.close()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[39], line 8
#       5 if flow_series.len() == 0:
#       6     continue
# ----> 8 data = city_df.filter(pl.col("flow") <= 2500).to_pandas()
#       9 plt.figure()
#      10 sns.histplot(data, x="flow")
#
# File ~\PycharmProjects\TrafficEngineering\.venv\Lib\site-packages\polars\dataframe\frame.py:2561, in DataFrame.to_pandas(self, use_pyarrow_extension_array, **kwargs)
#    2556 if Object in self.dtypes:
#    2557     return self._to_pandas_with_object_columns(
#    2558         use_pyarrow_extension_array=use_pyarrow_extension_array, **kwargs
#    2559     )
# -> 2561 return self._to_pandas_without_object_columns(
#    2562     self, use_pyarrow_extension_array=use_pyarrow_extension_array, **kwargs
#    2563 )
#
# File ~\PycharmProjects\TrafficEngineering\.venv\Lib\site-packages\polars\dataframe\frame.py:2623, in DataFrame._to_pandas_without_object_columns(self, df, use_pyarrow_extension_array, **kwargs)
#    2615     return tbl.to_pandas(
#    2616         self_destruct=True,
#    2617         split_blocks=True,
#    2618         types_mapper=lambda pa_dtype: pd.ArrowDtype(pa_dtype),
#    2619         **kwargs,
#    2620     )
#    2622 date_as_object = kwargs.pop("date_as_object", False)
# -> 2623 return tbl.to_pandas(date_as_object=date_as_object, **kwargs)
#
# File ~\PycharmProjects\TrafficEngineering\.venv\Lib\site-packages\pyarrow\array.pxi:1032, in pyarrow.lib._PandasConvertible.to_pandas()
#
# File ~\PycharmProjects\TrafficEngineering\.venv\Lib\site-packages\pyarrow\table.pxi:5177, in pyarrow.lib.Table._to_pandas()
#
# File ~\PycharmProjects\TrafficEngineering\.venv\Lib\site-packages\pyarrow\pandas_compat.py:811, in table_to_dataframe(options, table, categories, ignore_metadata, types_mapper)
#     808 columns = _deserialize_column_index(table, all_columns, column_indexes)
#     810 column_names = table.column_names
# --> 811 result = pa.lib.table_to_blocks(options, table, categories,
#     812                                 list(ext_columns_dtypes.keys()))
#     813 if _pandas_api.is_ge_v3():
#     814     from pandas.api.internals import create_dataframe_from_blocks
#
# File ~\PycharmProjects\TrafficEngineering\.venv\Lib\site-packages\pyarrow\table.pxi:4103, in pyarrow.lib.table_to_blocks()
#
# File ~\PycharmProjects\TrafficEngineering\.venv\Lib\site-packages\pyarrow\error.pxi:89, in pyarrow.lib.check_status()
#
# MemoryError: Unable to allocate 481. MiB for an array with shape (6, 10502829) and data type object

# %%
for city in cities:
    city_df = total_df.filter(pl.col("city") == city)
    occ_series = city_df["occ"].drop_nulls()
    if occ_series.len() == 0:
        continue

    data = city_df["occ"].drop_nulls().to_numpy()
    plt.figure()
    plt.hist(data)
    plt.title(f"{city.capitalize()} Occupancy Distribution")
    plt.xlabel("Occupancy [%]")
    plt.tight_layout()
    plt.savefig(f'./plots/histograms/occupancy/{city}_occupancy_histogram.png', dpi=300)
    plt.close()

# %%
for city in cities:
    city_df = total_df.filter(pl.col("city") == city)
    speed_series = city_df["speed"].drop_nulls()
    if speed_series.len() == 0:
        continue

    data = city_df["speed"].drop_nulls().to_numpy()
    plt.figure()
    plt.hist(data)
    plt.title(f"{city.capitalize()} Speed Distribution")
    plt.xlabel("Speed [km/h]")
    plt.tight_layout()
    plt.savefig(f'./plots/histograms/speed/{city}_speed_histogram.png', dpi=300)
    plt.close()

# %%
for city in cities:
    city_df = total_df.filter(pl.col("city") == city)
    summary_df = city_df[["flow", "occ", "speed"]]
    summary = summary_df.describe()
    psummary = summary.to_pandas()
    print(psummary.to_latex(index=False, na_rep='--', float_format="%.2f", bold_rows=True, column_format="r|lll",
                            caption=f"Summary Table for {city.capitalize()}", label=f"tab:summary-{city}"))
# Out:
# \begin{table}
# \caption{Summary Table for Bern}
# \label{tab:summary-bern}
# \begin{tabular}{r|lll}
# \toprule
# statistic & flow & occ & speed \\
# \midrule
# count & 773874.00 & 773874.00 & 0.00 \\
# null_count & 0.00 & 0.00 & 773874.00 \\
# mean & 201.96 & 0.14 & -- \\
# std & 171.27 & 0.18 & -- \\
# min & 0.00 & 0.00 & -- \\
# 25% & 60.20 & 0.01 & -- \\
# 50% & 180.00 & 0.06 & -- \\
# 75% & 299.40 & 0.19 & -- \\
# max & 11762.40 & 1.00 & -- \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \caption{Summary Table for Bordeaux}
# \label{tab:summary-bordeaux}
# \begin{tabular}{r|lll}
# \toprule
# statistic & flow & occ & speed \\
# \midrule
# count & 550436.00 & 550436.00 & 0.00 \\
# null_count & 0.00 & 0.00 & 550436.00 \\
# mean & 371.34 & 0.09 & -- \\
# std & 336.45 & 0.14 & -- \\
# min & 0.00 & 0.00 & -- \\
# 25% & 108.00 & 0.01 & -- \\
# 50% & 288.00 & 0.04 & -- \\
# 75% & 528.00 & 0.09 & -- \\
# max & 7992.00 & 1.00 & -- \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \caption{Summary Table for Hamburg}
# \label{tab:summary-hamburg}
# \begin{tabular}{r|lll}
# \toprule
# statistic & flow & occ & speed \\
# \midrule
# count & 10507107.00 & 10507107.00 & 0.00 \\
# null_count & 0.00 & 0.00 & 10507107.00 \\
# mean & 219.37 & 0.14 & -- \\
# std & 187.50 & 0.19 & -- \\
# min & 0.00 & 0.00 & -- \\
# 25% & 80.00 & 0.02 & -- \\
# 50% & 180.00 & 0.07 & -- \\
# 75% & 320.00 & 0.18 & -- \\
# max & 3600.00 & 1.00 & -- \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \caption{Summary Table for Innsbruck}
# \label{tab:summary-innsbruck}
# \begin{tabular}{r|lll}
# \toprule
# statistic & flow & occ & speed \\
# \midrule
# count & 128858.00 & 0.00 & 128858.00 \\
# null_count & 0.00 & 128858.00 & 0.00 \\
# mean & 401.16 & -- & 33.07 \\
# std & 396.48 & -- & 15.08 \\
# min & 0.00 & -- & 0.00 \\
# 25% & 96.00 & -- & 28.00 \\
# 50% & 291.60 & -- & 37.20 \\
# 75% & 588.00 & -- & 44.20 \\
# max & 3482.40 & -- & 77.40 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \caption{Summary Table for Zurich}
# \label{tab:summary-zurich}
# \begin{tabular}{r|lll}
# \toprule
# statistic & flow & occ & speed \\
# \midrule
# count & 3417568.00 & 3417568.00 & 0.00 \\
# null_count & 0.00 & 0.00 & 3417568.00 \\
# mean & 207.94 & 0.10 & -- \\
# std & 203.14 & 0.16 & -- \\
# min & 0.00 & 0.00 & -- \\
# 25% & 40.00 & 0.01 & -- \\
# 50% & 160.00 & 0.03 & -- \\
# 75% & 320.00 & 0.11 & -- \\
# max & 6240.00 & 28.34 & -- \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
mfd = (
    total_df
    .group_by(["city", "timestamp"])
    .agg([
        pl.sum("flow").alias("Q"),
        pl.mean("occ").alias("O"),
        (pl.col("flow") / pl.col("speed")).mean().alias("K"),
    ])
)
mfd.head()
# Out:
# shape: (5, 5)
# ┌─────────┬─────────────────────┬─────────┬──────────┬──────┐
# │ city    ┆ timestamp           ┆ Q       ┆ O        ┆ K    │
# │ ---     ┆ ---                 ┆ ---     ┆ ---      ┆ ---  │
# │ str     ┆ datetime[μs]        ┆ f64     ┆ f64      ┆ f64  │
# ╞═════════╪═════════════════════╪═════════╪══════════╪══════╡
# │ hamburg ┆ 2016-09-20 07:51:00 ┆ 84540.0 ┆ 0.224328 ┆ null │
# │ hamburg ┆ 2016-10-06 01:48:00 ┆ 4200.0  ┆ 0.025205 ┆ null │
# │ hamburg ┆ 2016-09-24 20:42:00 ┆ 47500.0 ┆ 0.130372 ┆ null │
# │ hamburg ┆ 2016-11-28 04:42:00 ┆ 8140.0  ┆ 0.020222 ┆ null │
# │ hamburg ┆ 2016-11-03 22:54:00 ┆ 33780.0 ┆ 0.080616 ┆ null │
# └─────────┴─────────────────────┴─────────┴──────────┴──────┘

# %%
day_dict = {1: "Monday", 2: "Tuesday", 7: "Sunday"}

for city in cities:
    if city != "innsbruck":
        city_df = mfd.filter(pl.col("city") == city)
        fig, axes = plt.subplots(3, figsize=(12, 12), sharex=True)
        fig.suptitle(f"MFD for {city.capitalize()}")
        for i, d in enumerate([1, 2, 7]):
            day_df = city_df.filter(pl.col("timestamp").dt.weekday() == d)
            axes[i].scatter(day_df["O"], day_df["Q"])
            axes[i].set_title(day_dict[d])
            axes[i].set_xlabel("Occupancy [%]")
            axes[i].set_ylabel("Flow [veh/h]")
    else:
        city_df = mfd.filter(pl.col("city") == city)
        fig, axes = plt.subplots(3, figsize=(12, 21), sharex=True)
        fig.suptitle(f"MFD for {city.capitalize()}")
        for i, d in enumerate([1, 2, 7]):
            day_df = city_df.filter(pl.col("timestamp").dt.weekday() == d)
            axes[i].scatter(day_df["K"], day_df["Q"])
            axes[i].set_title(day_dict[d])
            axes[i].set_xlabel("Density [veh/km]")
            axes[i].set_ylabel("Flow [veh/h]")
    plt.savefig(f"./plots/mfd/{city}_mfd.png", dpi=300)
    plt.close()
